# %%
import pandas as pd

tabela_produtos = {}

tabela_produtos['Nome'] = []
tabela_produtos['Nome'].append('Iphone')
tabela_produtos['Nome'].append('Ipad')
tabela_produtos['Nome'].append('Airpod')

tabela_produtos['Preço'] = []
tabela_produtos['Preço'].append(5000)
tabela_produtos['Preço'].append(9000)
tabela_produtos['Preço'].append(500)

tabela_produtos['Estoque'] = []
tabela_produtos['Estoque'].append(25)
tabela_produtos['Estoque'].append(15)
tabela_produtos['Estoque'].append(17)

print(tabela_produtos)

tp = pd.DataFrame(tabela_produtos)
display(tp)
# Out:
# {'Nome': ['Iphone', 'Ipad', 'Airpod'], 'Preço': [5000, 9000, 500], 'Estoque': [25, 15, 17]}
#      Nome  Preço  Estoque
# 0  Iphone   5000       25
# 1    Ipad   9000       15
# 2  Airpod    500       17
